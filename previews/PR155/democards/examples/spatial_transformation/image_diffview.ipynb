# %% [markdown]
# This demonstration shows some common tricks in image comparision -- difference view

# %% [markdown]
# People with MATLAB experiences would miss the function
# [`imshowpair`](https://www.mathworks.com/help/images/ref/imshowpair.html), but in JuliaImages
# it is not that indispensable.

# %%
using Images
using TestImages

img = float.(testimage("cameraman"))
# rotate img by 4 degrees and keep axes unchanged
img_r = imrotate(img, -pi/45, axes(img))
# Out:
# 512×512 Array{Gray{Float32},2} with eltype Gray{Float32}:
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)  …  Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)  …  Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  ⋮                                       ⋱
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)  …  Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)  …  Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)

# %% [markdown]
# `mosaicview` is a convenience tool to show multiple images, especially useful when they have
# different sizes and colors.

# %%
mosaicview(img, img_r; nrow=1, npad=20, fillvalue=colorant"white")
# Out:
# 512×1044 MosaicView{Gray{Float32},4,Base.ReshapedArray{Gray{Float32},4,PaddedView{Gray{Float32},3,Tuple{Base.OneTo{Int64},Base.OneTo{Int64},Base.OneTo{Int64}},Array{Gray{Float32},3}},Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float32}(0.611765)  Gray{Float32}(0.615686)  …  Gray{Float32}(NaN)
#  Gray{Float32}(0.611765)  Gray{Float32}(0.615686)     Gray{Float32}(NaN)
#  Gray{Float32}(0.619608)  Gray{Float32}(0.615686)     Gray{Float32}(NaN)
#  Gray{Float32}(0.627451)  Gray{Float32}(0.615686)     Gray{Float32}(NaN)
#  Gray{Float32}(0.619608)  Gray{Float32}(0.615686)     Gray{Float32}(NaN)
#  Gray{Float32}(0.611765)  Gray{Float32}(0.615686)  …  Gray{Float32}(NaN)
#  Gray{Float32}(0.619608)  Gray{Float32}(0.615686)     Gray{Float32}(NaN)
#  Gray{Float32}(0.627451)  Gray{Float32}(0.615686)     Gray{Float32}(NaN)
#  Gray{Float32}(0.619608)  Gray{Float32}(0.607843)     Gray{Float32}(NaN)
#  Gray{Float32}(0.611765)  Gray{Float32}(0.603922)     Gray{Float32}(NaN)
#  ⋮                                                 ⋱
#  Gray{Float32}(0.384314)  Gray{Float32}(0.415686)     Gray{Float32}(NaN)
#  Gray{Float32}(0.435294)  Gray{Float32}(0.439216)     Gray{Float32}(NaN)
#  Gray{Float32}(0.494118)  Gray{Float32}(0.47451)   …  Gray{Float32}(NaN)
#  Gray{Float32}(0.47451)   Gray{Float32}(0.482353)     Gray{Float32}(NaN)
#  Gray{Float32}(0.447059)  Gray{Float32}(0.486275)     Gray{Float32}(NaN)
#  Gray{Float32}(0.454902)  Gray{Float32}(0.482353)     Gray{Float32}(NaN)
#  Gray{Float32}(0.47451)   Gray{Float32}(0.482353)     Gray{Float32}(NaN)
#  Gray{Float32}(0.47451)   Gray{Float32}(0.482353)  …  Gray{Float32}(NaN)
#  Gray{Float32}(0.47451)   Gray{Float32}(0.482353)     Gray{Float32}(NaN)

# %% [markdown]
# In some cases, when the differences of two images are relative insignificant, a plain
# substraction can help amplify the difference.

# %%
plain_diffview = @. img - img_r
# Out:
# 512×512 Array{Gray{Float32},2} with eltype Gray{Float32}:
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)  …  Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)  …  Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  ⋮                                       ⋱
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)  …  Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)  …  Gray{Float32}(NaN)
#  Gray{Float32}(NaN)  Gray{Float32}(NaN)     Gray{Float32}(NaN)

# %% [markdown]
# For gray images, a fancy trick is to fill each image into different RGB channels
# and make a RGB view

# %%
RGB_diffview = colorview(RGB, channelview(img), channelview(img_r), fill(0., size(img)))
# Out:
# 512×512 mappedarray(RGB{Float64}, ImageCore.extractchannels, reinterpret(Float32, ::Array{Gray{Float32},2}), reinterpret(Float32, ::Array{Gray{Float32},2}), ::Array{Float64,2}) with eltype RGB{Float64}:
#  RGB{Float64}(0.611765,NaN,0.0)  …  RGB{Float64}(0.596078,NaN,0.0)
#  RGB{Float64}(0.611765,NaN,0.0)     RGB{Float64}(0.596078,NaN,0.0)
#  RGB{Float64}(0.619608,NaN,0.0)     RGB{Float64}(0.596078,NaN,0.0)
#  RGB{Float64}(0.627451,NaN,0.0)     RGB{Float64}(0.596078,NaN,0.0)
#  RGB{Float64}(0.619608,NaN,0.0)     RGB{Float64}(0.596078,NaN,0.0)
#  RGB{Float64}(0.611765,NaN,0.0)  …  RGB{Float64}(0.6,NaN,0.0)
#  RGB{Float64}(0.619608,NaN,0.0)     RGB{Float64}(0.6,NaN,0.0)
#  RGB{Float64}(0.627451,NaN,0.0)     RGB{Float64}(0.6,NaN,0.0)
#  RGB{Float64}(0.619608,NaN,0.0)     RGB{Float64}(0.596078,NaN,0.0)
#  RGB{Float64}(0.611765,NaN,0.0)     RGB{Float64}(0.596078,NaN,0.0)
#  ⋮                               ⋱
#  RGB{Float64}(0.384314,NaN,0.0)     RGB{Float64}(0.411765,NaN,0.0)
#  RGB{Float64}(0.435294,NaN,0.0)     RGB{Float64}(0.439216,NaN,0.0)
#  RGB{Float64}(0.494118,NaN,0.0)  …  RGB{Float64}(0.466667,NaN,0.0)
#  RGB{Float64}(0.47451,NaN,0.0)      RGB{Float64}(0.45098,NaN,0.0)
#  RGB{Float64}(0.447059,NaN,0.0)     RGB{Float64}(0.431373,NaN,0.0)
#  RGB{Float64}(0.454902,NaN,0.0)     RGB{Float64}(0.427451,NaN,0.0)
#  RGB{Float64}(0.47451,NaN,0.0)      RGB{Float64}(0.435294,NaN,0.0)
#  RGB{Float64}(0.47451,NaN,0.0)   …  RGB{Float64}(0.435294,NaN,0.0)
#  RGB{Float64}(0.47451,NaN,0.0)      RGB{Float64}(0.435294,NaN,0.0)

# %% [markdown]
# or convert the RGB view back to Gray image after that

# %%
Gray_diffview = Gray.(RGB_diffview)

mosaicview(plain_diffview, RGB_diffview, Gray_diffview;
           nrow=1, npad=20, fillvalue=colorant"white")
# Out:
# 512×1576 MosaicView{RGB{Float64},4,Base.ReshapedArray{RGB{Float64},4,PaddedView{RGB{Float64},3,Tuple{Base.OneTo{Int64},Base.OneTo{Int64},Base.OneTo{Int64}},Array{RGB{Float64},3}},Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  RGB{Float64}(NaN,NaN,NaN)  …  RGB{Float64}(NaN,NaN,NaN)
#  RGB{Float64}(NaN,NaN,NaN)     RGB{Float64}(NaN,NaN,NaN)
#  RGB{Float64}(NaN,NaN,NaN)     RGB{Float64}(NaN,NaN,NaN)
#  RGB{Float64}(NaN,NaN,NaN)     RGB{Float64}(NaN,NaN,NaN)
#  RGB{Float64}(NaN,NaN,NaN)     RGB{Float64}(NaN,NaN,NaN)
#  RGB{Float64}(NaN,NaN,NaN)  …  RGB{Float64}(NaN,NaN,NaN)
#  RGB{Float64}(NaN,NaN,NaN)     RGB{Float64}(NaN,NaN,NaN)
#  RGB{Float64}(NaN,NaN,NaN)     RGB{Float64}(NaN,NaN,NaN)
#  RGB{Float64}(NaN,NaN,NaN)     RGB{Float64}(NaN,NaN,NaN)
#  RGB{Float64}(NaN,NaN,NaN)     RGB{Float64}(NaN,NaN,NaN)
#  ⋮                          ⋱  ⋮
#  RGB{Float64}(NaN,NaN,NaN)     RGB{Float64}(NaN,NaN,NaN)
#  RGB{Float64}(NaN,NaN,NaN)     RGB{Float64}(NaN,NaN,NaN)
#  RGB{Float64}(NaN,NaN,NaN)  …  RGB{Float64}(NaN,NaN,NaN)
#  RGB{Float64}(NaN,NaN,NaN)     RGB{Float64}(NaN,NaN,NaN)
#  RGB{Float64}(NaN,NaN,NaN)     RGB{Float64}(NaN,NaN,NaN)
#  RGB{Float64}(NaN,NaN,NaN)     RGB{Float64}(NaN,NaN,NaN)
#  RGB{Float64}(NaN,NaN,NaN)     RGB{Float64}(NaN,NaN,NaN)
#  RGB{Float64}(NaN,NaN,NaN)  …  RGB{Float64}(NaN,NaN,NaN)
#  RGB{Float64}(NaN,NaN,NaN)     RGB{Float64}(NaN,NaN,NaN)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
